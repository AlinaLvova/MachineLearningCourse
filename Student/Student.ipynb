# %% [markdown]
# ### Задача бинарной классификации
#
# ## Students' Academic Performance Dataset
#
# Data Set Characteristics: Multivariate
#
# Number of Instances: 480
#
# Area: E-learning, Education, Predictive models, Educational Data Mining
#
# Attribute Characteristics: Integer/Categorical
#
# Number of Attributes: 16
#
# Date: 2016-11-8
#
# Associated Tasks: Classification
#
# Missing Values? No
#
# File formats: xAPI-Edu-Data.csv
#
# ## Банк данных --> [Data Set](https://www.kaggle.com/aljarah/xAPI-Edu-Data)
#
# ## 1. Dataset Information
#
# This is an educational data set which is collected from learning management system (LMS) called Kalboard 360. Kalboard 360 is a multi-agent LMS, which has been designed to facilitate learning through the use of leading-edge technology. Such system provides users with a synchronous access to educational resources from any device with Internet connection.
#
#
# ## 2. Attributes
#
# 1 Gender - student's gender (nominal: 'Male' or 'Female’)
#
# 2 Nationality- student's nationality (nominal:’ Kuwait’,’ Lebanon’,’ Egypt’,’ SaudiArabia’,’ USA’,’ Jordan’,’ Venezuela’,’ Iran’,’ Tunis’,’ Morocco’,’ Syria’,’ Palestine’,’ Iraq’,’ Lybia’)
#
# 3 Place of birth- student's Place of birth (nominal:’ Kuwait’,’ Lebanon’,’ Egypt’,’ SaudiArabia’,’ USA’,’ Jordan’,’ Venezuela’,’ Iran’,’ Tunis’,’ Morocco’,’ Syria’,’ Palestine’,’ Iraq’,’ Lybia’)
#
# 4 Educational Stages- educational level student belongs (nominal: ‘lowerlevel’,’MiddleSchool’,’HighSchool’)
#
# 5 Grade Levels- grade student belongs (nominal: ‘G-01’, ‘G-02’, ‘G-03’, ‘G-04’, ‘G-05’, ‘G-06’, ‘G-07’, ‘G-08’, ‘G-09’, ‘G-10’, ‘G-11’, ‘G-12 ‘)
#
# 6 Section ID- classroom student belongs (nominal:’A’,’B’,’C’)
#
# 7 Topic- course topic (nominal:’ English’,’ Spanish’, ‘French’,’ Arabic’,’ IT’,’ Math’,’ Chemistry’, ‘Biology’, ‘Science’,’ History’,’ Quran’,’ Geology’)
#
# 8 Semester- school year semester (nominal:’ First’,’ Second’)
#
# 9 Parent responsible for student (nominal:’mom’,’father’)
#
# 10 Raised hand- how many times the student raises his/her hand on classroom (numeric:0-100)
#
# 11- Visited resources- how many times the student visits a course content(numeric:0-100)
#
# 12 Viewing announcements-how many times the student checks the new announcements(numeric:0-100)
#
# 13 Discussion groups- how many times the student participate on discussion groups (numeric:0-100)
#
# 14 Parent Answering Survey- parent answered the surveys which are provided from school or not (nominal:’Yes’,’No’)
#
# 15 Parent School Satisfaction- the Degree of parent satisfaction from school(nominal:’Yes’,’No’)
#
# 16 Student Absence Days-the number of absence days for each student (nominal: above-7, under-7)
#
# #### The students are classified into three numerical intervals based on their total grade/mark:
# Low-Level: interval includes values from 0 to 69,
#
# Middle-Level: interval includes values from 70 to 89,
#
# High-Level: interval includes values from 90-100.
#
# ## 3. Relevant Papers:
# Amrieh, E. A., Hamtini, T., & Aljarah, I. (2016). Mining Educational Data to Predict Student’s academic Performance using Ensemble Methods. International Journal of Database Theory and Application, 9(8), 119-136.
#
# Amrieh, E. A., Hamtini, T., & Aljarah, I. (2015, November). Preprocessing and analyzing educational data set using X-API for improving student's performance. In Applied Electrical Engineering and Computing Technologies (AEECT), 2015 IEEE Jordan Conference on (pp. 1-5). IEEE.
#
# ## 4.Citation Request:
# Please include these citations if you plan to use this dataset:
#
# Amrieh, E. A., Hamtini, T., & Aljarah, I. (2016). Mining Educational Data to Predict Student’s academic Performance using Ensemble Methods. International Journal of Database Theory and Application, 9(8), 119-136.
#
# Amrieh, E. A., Hamtini, T., & Aljarah, I. (2015, November). Preprocessing and analyzing educational data set using X-API for improving student's performance. In Applied Electrical Engineering and Computing Technologies (AEECT), 2015 IEEE Jordan Conference on (pp. 1-5). IEEE.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn-deep')
# %matplotlib inline

# %%
data = pd.read_csv('Student.csv', sep = ',', engine = 'python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (480, 17)

# %%
data
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# 5        F          KW       KuwaIT    lowerlevel    G-04         A
# 6        M          KW       KuwaIT  MiddleSchool    G-07         A
# 7        M          KW       KuwaIT  MiddleSchool    G-07         A
# 8        F          KW       KuwaIT  MiddleSchool    G-07         A
# 9        F          KW       KuwaIT  MiddleSchool    G-07         B
# 10       M          KW       KuwaIT  MiddleSchool    G-07         A
# 11       M          KW       KuwaIT  MiddleSchool    G-07         B
# 12       M          KW       KuwaIT    lowerlevel    G-04         A
# ...

# %%
print(data)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# 5        F          KW       KuwaIT    lowerlevel    G-04         A
# 6        M          KW       KuwaIT  MiddleSchool    G-07         A
# 7        M          KW       KuwaIT  MiddleSchool    G-07         A
# 8        F          KW       KuwaIT  MiddleSchool    G-07         A
# 9        F          KW       KuwaIT  MiddleSchool    G-07         B
# 10       M          KW       KuwaIT  MiddleSchool    G-07         A
# 11       M          KW       KuwaIT  MiddleSchool    G-07         B
# 12       M          KW       KuwaIT    lowerlevel    G-04         A
# ...

# %%
data.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
data.tail()
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 475  Chemistry        S   Father            5                 4
# 476    Geology        F   Father           50                77
# 477    Geology        S   Father           55                74
# 478    History        F   Father           30                17
# 479    History        S   Father           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 475                  5           8                    No
# ...

# %%
print(data.shape)
print(data.columns)
# Out:
# (480, 17)
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=480, step=1)

# %%
data.at[3, 'GradeID']
# Out:
# 'G-04'

# %%
data['GradeID']
# Out:
# 0      G-04
# 1      G-04
# 2      G-04
# 3      G-04
# 4      G-04
# 5      G-04
# 6      G-07
# 7      G-07
# 8      G-07
# 9      G-07
# 10     G-07
# 11     G-07
# 12     G-04
# 13     G-08
# 14     G-08
# 15     G-06
# 16     G-07
# 17     G-07
# 18     G-07
# 19     G-07
# 20     G-07
# 21     G-07
# 22     G-07
# 23     G-07
# 24     G-07
# 25     G-07
# 26     G-07
# 27     G-08
# 28     G-08
# 29     G-08
#        ...
# 450    G-08
# 451    G-08
# 452    G-08
# 453    G-08
# 454    G-08
# 455    G-08
# 456    G-08
# 457    G-08
# 458    G-08
# 459    G-08
# 460    G-08
# 461    G-08
# 462    G-08
# 463    G-08
# 464    G-08
# 465    G-08
# 466    G-08
# 467    G-08
# 468    G-08
# 469    G-08
# 470    G-08
# 471    G-08
# 472    G-08
# 473    G-08
# 474    G-08
# 475    G-08
# 476    G-08
# 477    G-08
# 478    G-08
# 479    G-08
# Name: GradeID, Length: 480, dtype: object

# %%
data['GradeID'][10]
# Out:
# 'G-07'

# %%
data['GradeID'].dtype.name
# Out:
# 'object'

# %%
data['raisedhands'].dtype.name
# Out:
# 'int64'

# %%
type(data['raisedhands'][3])
# Out:
# numpy.int64

# %%
type(data['raisedhands'])
# Out:
# pandas.core.series.Series

# %%
data[['raisedhands', 'GradeID']].head()
# Out:
#    raisedhands GradeID
# 0           15    G-04
# 1           20    G-04
# 2           10    G-04
# 3           30    G-04
# 4           40    G-04

# %%
data[['raisedhands', 'GradeID']].tail()
# Out:
#      raisedhands GradeID
# 475            5    G-08
# 476           50    G-08
# 477           55    G-08
# 478           30    G-08
# 479           35    G-08

# %%
data.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = 0.35, figsize = (9, 9), color='green')
pass

# %%
data.corr()
# Out:
#                    raisedhands  VisITedResources  AnnouncementsView  \
# raisedhands           1.000000          0.691572           0.643918
# VisITedResources      0.691572          1.000000           0.594500
# AnnouncementsView     0.643918          0.594500           1.000000
# Discussion            0.339386          0.243292           0.417290
#
#                    Discussion
# raisedhands          0.339386
# VisITedResources     0.243292
# AnnouncementsView    0.417290
# Discussion           1.000000

# %%
plt.plot(data['GradeID'], data['Discussion'], 'o', alpha = 0.15)
plt.xlabel('GradeID')
plt.ylabel('Discussion')
plt.title('GradeID vs Discussion')
pass

# %%
plt.plot(data['raisedhands'], data['Discussion'], 'o', alpha = 0.25)
plt.xlabel('raisedhands')
plt.ylabel('Discussion')
plt.title('raisedhands vs Discussion')
pass

# %%
data['Topic'] == 'IT'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12      True
# 13     False
# 14     False
# 15      True
# 16      True
# 17     False
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27     False
# 28     False
# 29     False
#        ...
# 450    False
# 451    False
# 452    False
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# 458    False
# 459    False
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# 465    False
# 466    False
# 467    False
# 468    False
# 469    False
# 470    False
# 471    False
# 472    False
# 473    False
# 474    False
# 475    False
# 476    False
# 477    False
# 478    False
# 479    False
# Name: Topic, Length: 480, dtype: bool

# %%
data['Topic'].unique()
# Out:
# array(['IT', 'Math', 'Arabic', 'Science', 'English', 'Quran', 'Spanish',
#        'French', 'History', 'Biology', 'Chemistry', 'Geology'],
#       dtype=object)

# %% [markdown]
# Ниже зависимость данных:

# %%
plt.figure(figsize = (13, 8))
ind = np.arange(13)

plt.scatter(data[data['gender'] == 'M']['Topic'],
            data[data['gender'] == 'M']['raisedhands'],
            alpha = 0.3,
            label = 'Male',
            color = 'magenta')

plt.scatter(data[data['gender'] == 'F']['Topic'],
            data[data['gender'] == 'F']['raisedhands'],
            alpha = 0.3,
            label = 'Female',
            color = 'green')

plt.xlabel('Topic')
plt.xticks(ind, ('IT', 'Math', 'Arabic', 'Science', 'English', 'Quran', 'Spanish',
       'French', 'History', 'Biology', 'Chemistry', 'Geology'))
plt.xlim(-1, 13)
plt.ylabel('raisedhands')
plt.legend()
plt.grid()

# %% [markdown]
# Зависимость данных:

# %%
plt.figure(figsize = (13, 3))
ind = np.arange(13)

plt.scatter(data[data['gender'] == 'M']['raisedhands'],
            data[data['gender'] == 'M']['Class'],
            alpha = 0.3,
            label = 'Male',
            color = 'magenta')

plt.scatter(data[data['gender'] == 'F']['raisedhands'],
            data[data['gender'] == 'F']['Class'],
            alpha = 0.3,
            label = 'Female',
            color = 'green')

plt.xlabel('raisedhands')
plt.xticks(range(50,70))
plt.xlim(49, 71)
plt.ylabel('Class')
plt.legend()
plt.grid()

# %%
np.random.seed(0)
rnd = data['raisedhands'] + np.random.rand(data.shape[0]) - .5

plt.figure(figsize = (13, 8))
ind = np.arange(13)

plt.scatter(rnd[data['gender'] == 'M'],
            data[data['gender'] == 'M']['Class'],
            alpha = 0.3,
            label = 'Male',
            color = 'magenta')

plt.scatter(rnd[data['gender'] == 'F'],
            data[data['gender'] == 'F']['Class'],
            alpha = 0.3,
            label = 'Female',
            color = 'green')

plt.xlabel('raisedhands')
plt.xticks(range(50,70))
plt.xlim(49, 71)
plt.ylabel('Class')
plt.legend()
plt.grid()

# %% [markdown]
# Зависимость данных: количество самоубийств - возраст / расширенная.

# %%
plt.figure(figsize = (15, 15))

plt.scatter(data[data['Semester'] == 'F']['Class'],
            data[data['Semester'] == 'F']['raisedhands'],
            alpha = 0.3,
            label = 'First',
            color = 'magenta')

plt.scatter(data[data['Semester'] == 'S']['Class'],
            data[data['Semester'] == 'S']['raisedhands'],
            alpha = 0.3,
            label = 'Second',
            color = 'green')

plt.xlabel('Class')

plt.ylabel('raisedhands')
plt.yticks(range(0,100))
plt.ylim(-1, 101)
plt.legend()
plt.grid()

# %%
np.random.seed(0)
rnd = data['raisedhands'] + np.random.rand(data.shape[0]) - .5

plt.figure(figsize = (15, 15))

plt.scatter(data[data['Semester'] == 'F']['Class'],
            rnd[data['Semester'] == 'F'],
            alpha = 0.3,
            label = 'First',
            color = 'magenta')

plt.scatter(data[data['Semester'] == 'S']['Class'],
            rnd[data['Semester'] == 'S'],
            alpha = 0.3,
            label = 'Second',
            color = 'green')

plt.xlabel('Class')

plt.ylabel('raisedhands')
plt.yticks(range(0,100))
plt.ylim(-1, 101)
plt.legend()
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#        gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# count     480         480          480           480     480       480   480
# unique      2          14           14             3      10         3    12
# top         M          KW       KuwaIT  MiddleSchool    G-02         A    IT
# freq      305         179          180           248     147       283    95
#
#        Semester Relation ParentAnsweringSurvey ParentschoolSatisfaction  \
# count       480      480                   480                      480
# unique        2        2                     2                        2
# top           F   Father                   Yes                     Good
# freq        245      283                   270                      292
#
#        StudentAbsenceDays Class
# count                 480   480
# unique                  2     3
# top               Under-7     M
# freq                  289   211

# %%
data.describe(include = 'all')
# Out:
#        gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# count     480         480          480           480     480       480   480
# unique      2          14           14             3      10         3    12
# top         M          KW       KuwaIT  MiddleSchool    G-02         A    IT
# freq      305         179          180           248     147       283    95
# mean      NaN         NaN          NaN           NaN     NaN       NaN   NaN
# std       NaN         NaN          NaN           NaN     NaN       NaN   NaN
# min       NaN         NaN          NaN           NaN     NaN       NaN   NaN
# 25%       NaN         NaN          NaN           NaN     NaN       NaN   NaN
# 50%       NaN         NaN          NaN           NaN     NaN       NaN   NaN
# 75%       NaN         NaN          NaN           NaN     NaN       NaN   NaN
# max       NaN         NaN          NaN           NaN     NaN       NaN   NaN
#
# ...

# %%
data['GradeID'].unique()
# Out:
# array(['G-04', 'G-07', 'G-08', 'G-06', 'G-05', 'G-09', 'G-12', 'G-11',
#        'G-10', 'G-02'], dtype=object)

# %%
data['Topic'].unique()
# Out:
# array(['IT', 'Math', 'Arabic', 'Science', 'English', 'Quran', 'Spanish',
#        'French', 'History', 'Biology', 'Chemistry', 'Geology'],
#       dtype=object)

# %%
for name in data['Topic'].unique():
    print(name, data['GradeID'][data['Topic'] == name].iloc[1])
# Out:
# IT G-04
# Math G-07
# Arabic G-08
# Science G-07
# English G-07
# Quran G-07
# Spanish G-08
# French G-02
# History G-04
# Biology G-07
# Chemistry G-08
# Geology G-08

# %% [markdown]
# ### Задача
#
# Усложним задачу, убрав параметры
# *

# %%
data = data.drop('StageID', axis = 1)\
            .drop('PlaceofBirth', axis = 1)\
            .drop('SectionID', axis = 1)\
            .drop('NationalITy', axis = 1)\
            .drop('raisedhands', axis = 1)

# %%
#data.drop(['gdp_per_capita ($)'], axis = 1)

# %% [markdown]
# ### Готовим данные

# %%
data.dtypes
# Out:
# gender                      object
# GradeID                     object
# Topic                       object
# Semester                    object
# Relation                    object
# VisITedResources             int64
# AnnouncementsView            int64
# Discussion                   int64
# ParentAnsweringSurvey       object
# ParentschoolSatisfaction    object
# StudentAbsenceDays          object
# Class                       object
# dtype: object

# %%
data.describe()
# Out:
#        VisITedResources  AnnouncementsView  Discussion
# count        480.000000         480.000000  480.000000
# mean          54.797917          37.918750   43.283333
# std           33.080007          26.611244   27.637735
# min            0.000000           0.000000    1.000000
# 25%           20.000000          14.000000   20.000000
# 50%           65.000000          33.000000   39.000000
# 75%           84.000000          58.000000   70.000000
# max           99.000000          98.000000   99.000000

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['gender', 'GradeID', 'Topic', 'Semester', 'Relation', 'ParentAnsweringSurvey', 'ParentschoolSatisfaction', 'StudentAbsenceDays', 'Class']
# ['VisITedResources', 'AnnouncementsView', 'Discussion']

# %%
data[categorical_columns].describe()
# Out:
#        gender GradeID Topic Semester Relation ParentAnsweringSurvey  \
# count     480     480   480      480      480                   480
# unique      2      10    12        2        2                     2
# top         M    G-02    IT        F   Father                   Yes
# freq      305     147    95      245      283                   270
#
#        ParentschoolSatisfaction StudentAbsenceDays Class
# count                       480                480   480
# unique                        2                  2     3
# top                        Good            Under-7     M
# freq                        292                289   211

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# gender ['M' 'F']
# GradeID ['G-04' 'G-07' 'G-08' 'G-06' 'G-05' 'G-09' 'G-12' 'G-11' 'G-10' 'G-02']
# Topic ['IT' 'Math' 'Arabic' 'Science' 'English' 'Quran' 'Spanish' 'French'
#  'History' 'Biology' 'Chemistry' 'Geology']
# Semester ['F' 'S']
# Relation ['Father' 'Mum']
# ParentAnsweringSurvey ['Yes' 'No']
# ParentschoolSatisfaction ['Good' 'Bad']
# StudentAbsenceDays ['Under-7' 'Above-7']
# Class ['M' 'L' 'H']

# %%
data.corr()
# Out:
#                    VisITedResources  AnnouncementsView  Discussion
# VisITedResources           1.000000            0.59450    0.243292
# AnnouncementsView          0.594500            1.00000    0.417290
# Discussion                 0.243292            0.41729    1.000000

# %% [markdown]
# ### Обрабатываем пропущенные значения
# Если данные содержат пропущенные значения, то имеется две простые альтернативы:
#
# удалить столбцы с такими значениями (data = data.dropna(axis = 1)),
# удалить строки с такими значениями (data = data.dropna(axis = 0)).
# После этого данных может стать совсем мало.
#
# Куда более эффективным (и в то же время по-прежнему простым) методом обычно является заполнение пропущенных значений для каждой количественной переменной их средним или медианным значением. Для категориальных признаков пропущенные значения можно заполнить самым популярным значением в столбце.

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data.count(axis=0)
# Out:
# gender                      480
# GradeID                     480
# Topic                       480
# Semester                    480
# Relation                    480
# VisITedResources            480
# AnnouncementsView           480
# Discussion                  480
# ParentAnsweringSurvey       480
# ParentschoolSatisfaction    480
# StudentAbsenceDays          480
# Class                       480
# dtype: int64

# %%
data_describe = data.describe(include=[object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
data.describe(include=[object])
# Out:
#        gender GradeID Topic Semester Relation ParentAnsweringSurvey  \
# count     480     480   480      480      480                   480
# unique      2      10    12        2        2                     2
# top         M    G-02    IT        F   Father                   Yes
# freq      305     147    95      245      283                   270
#
#        ParentschoolSatisfaction StudentAbsenceDays Class
# count                       480                480   480
# unique                        2                  2     3
# top                        Good            Under-7     M
# freq                        292                289   211

# %% [markdown]
# ### Векторизация

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# ['gender', 'Semester', 'Relation', 'ParentAnsweringSurvey', 'ParentschoolSatisfaction', 'StudentAbsenceDays'] ['GradeID', 'Topic', 'Class']

# %%
data['gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
data.at[data['gender'] == 'M', 'gender'] = 0
data.at[data['gender'] == 'F', 'gender'] = 1
data['gender'].describe()
# Out:
# count    480.000000
# mean       0.364583
# std        0.481815
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: gender, dtype: float64

# %%
for c in binary_columns:
    data_binary_unique = data[c].unique()
    data[c] = data[c].replace(data_binary_unique[0], 0)
    data[c] = data[c].replace(data_binary_unique[1], 1)

# %%
for c in binary_columns:
    print(c, data[c].unique())
# Out:
# gender [0 1]
# Semester [0 1]
# Relation [0 1]
# ParentAnsweringSurvey [0 1]
# ParentschoolSatisfaction [0 1]
# StudentAbsenceDays [0 1]

# %%
data[binary_columns].describe()
# Out:
#            gender    Semester    Relation  ParentAnsweringSurvey  \
# count  480.000000  480.000000  480.000000             480.000000
# mean     0.364583    0.489583    0.410417               0.437500
# std      0.481815    0.500413    0.492423               0.496596
# min      0.000000    0.000000    0.000000               0.000000
# 25%      0.000000    0.000000    0.000000               0.000000
# 50%      0.000000    0.000000    0.000000               0.000000
# 75%      1.000000    1.000000    1.000000               1.000000
# max      1.000000    1.000000    1.000000               1.000000
#
#        ParentschoolSatisfaction  StudentAbsenceDays
# count                480.000000          480.000000
# mean                   0.391667            0.397917
# std                    0.488632            0.489979
# min                    0.000000            0.000000
# 25%                    0.000000            0.000000
# 50%                    0.000000            0.000000
# ...

# %% [markdown]
# ## Небинарные признаки
#
# К небинарными признакам применим метод векторизации, который заключается в следующем.
#
# Признак j, принимающий s значений, заменим на s признаков, принимащих значения 0 или 1, в зависимости от того, чему равно значение исходного признака j.
#
# Например, в нашей задаче признак A4 принимает 3 различных значения:

# %%
data['Class'].unique()
# Out:
# array(['M', 'L', 'H'], dtype=object)

# %%
data_nonbinary = pd.get_dummies(data[nonbinary_columns])

# %%
print(data_nonbinary.columns)
# Out:
# Index(['GradeID_G-02', 'GradeID_G-04', 'GradeID_G-05', 'GradeID_G-06',
#        'GradeID_G-07', 'GradeID_G-08', 'GradeID_G-09', 'GradeID_G-10',
#        'GradeID_G-11', 'GradeID_G-12', 'Topic_Arabic', 'Topic_Biology',
#        'Topic_Chemistry', 'Topic_English', 'Topic_French', 'Topic_Geology',
#        'Topic_History', 'Topic_IT', 'Topic_Math', 'Topic_Quran',
#        'Topic_Science', 'Topic_Spanish', 'Class_H', 'Class_L', 'Class_M'],
#       dtype='object')

# %% [markdown]
# ### Нормализация количественных признаков

# %% [markdown]
# Многие алгоритмы машинного обучения чувствительны к масштабированию данных. К таким алгоритмам, например, относится метод ближайших соседей, машина опорных векторов и др.
#
# В этом случае количественные признаки полезно нормализовать. Это можно делать разными способами. Например, каждый количественный признак приведем к нулевому среднему и единичному среднеквадратичному отклонению:

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#        VisITedResources  AnnouncementsView  Discussion
# count        480.000000         480.000000  480.000000
# mean          54.797917          37.918750   43.283333
# std           33.080007          26.611244   27.637735
# min            0.000000           0.000000    1.000000
# 25%           20.000000          14.000000   20.000000
# 50%           65.000000          33.000000   39.000000
# 75%           84.000000          58.000000   70.000000
# max           99.000000          98.000000   99.000000

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#        VisITedResources  AnnouncementsView    Discussion
# count      4.800000e+02       4.800000e+02  4.800000e+02
# mean      -1.942890e-17       8.465451e-17  2.197316e-17
# std        1.000000e+00       1.000000e+00  1.000000e+00
# min       -1.656527e+00      -1.424915e+00 -1.529913e+00
# 25%       -1.051932e+00      -8.988212e-01 -8.424472e-01
# 50%        3.084063e-01      -1.848373e-01 -1.549813e-01
# 75%        8.827714e-01       7.546152e-01  9.666735e-01
# max        1.336217e+00       2.257739e+00  2.015964e+00

# %% [markdown]
# ### Соединяем все в одну таблицу

# %%
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns]), axis = 1)

print(data.shape)
print(data.columns)
data['StudentAbsenceDays'].dtype
# Out:
# (480, 34)
# Index(['VisITedResources', 'AnnouncementsView', 'Discussion', 'GradeID_G-02',
#        'GradeID_G-04', 'GradeID_G-05', 'GradeID_G-06', 'GradeID_G-07',
#        'GradeID_G-08', 'GradeID_G-09', 'GradeID_G-10', 'GradeID_G-11',
#        'GradeID_G-12', 'Topic_Arabic', 'Topic_Biology', 'Topic_Chemistry',
#        'Topic_English', 'Topic_French', 'Topic_Geology', 'Topic_History',
#        'Topic_IT', 'Topic_Math', 'Topic_Quran', 'Topic_Science',
#        'Topic_Spanish', 'Class_H', 'Class_L', 'Class_M', 'gender', 'Semester',
#        'Relation', 'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays'],
#       dtype='object')
# dtype('int64')

# %%
data.describe()
# Out:
#        VisITedResources  AnnouncementsView    Discussion  GradeID_G-02  \
# count      4.800000e+02       4.800000e+02  4.800000e+02    480.000000
# mean      -1.942890e-17       8.465451e-17  2.197316e-17      0.306250
# std        1.000000e+00       1.000000e+00  1.000000e+00      0.461416
# min       -1.656527e+00      -1.424915e+00 -1.529913e+00      0.000000
# 25%       -1.051932e+00      -8.988212e-01 -8.424472e-01      0.000000
# 50%        3.084063e-01      -1.848373e-01 -1.549813e-01      0.000000
# 75%        8.827714e-01       7.546152e-01  9.666735e-01      1.000000
# max        1.336217e+00       2.257739e+00  2.015964e+00      1.000000
#
#        GradeID_G-04  GradeID_G-05  GradeID_G-06  GradeID_G-07  GradeID_G-08  \
# count    480.000000    480.000000    480.000000    480.000000    480.000000
# mean       0.100000      0.006250      0.066667      0.210417      0.241667
# std        0.300313      0.078892      0.249704      0.408030      0.428540
# ...

# %% [markdown]
# ### X и y

# %%
X = data.drop(('StudentAbsenceDays'), axis = 1)
y = data['StudentAbsenceDays']
feature_names = X.columns
print(feature_names)
# Out:
# Index(['VisITedResources', 'AnnouncementsView', 'Discussion', 'GradeID_G-02',
#        'GradeID_G-04', 'GradeID_G-05', 'GradeID_G-06', 'GradeID_G-07',
#        'GradeID_G-08', 'GradeID_G-09', 'GradeID_G-10', 'GradeID_G-11',
#        'GradeID_G-12', 'Topic_Arabic', 'Topic_Biology', 'Topic_Chemistry',
#        'Topic_English', 'Topic_French', 'Topic_Geology', 'Topic_History',
#        'Topic_IT', 'Topic_Math', 'Topic_Quran', 'Topic_Science',
#        'Topic_Spanish', 'Class_H', 'Class_L', 'Class_M', 'gender', 'Semester',
#        'Relation', 'ParentAnsweringSurvey', 'ParentschoolSatisfaction'],
#       dtype='object')

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (480, 33)
# (480,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 10)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 360 120

# %%
y_train[y_train==1].shape
# Out:
# (137,)

# %%
y_train[y_train==1].shape[0]/N_train
# Out:
# 0.38055555555555554

# %%
y_test[y_test==1].shape[0]/N_test
# Out:
# 0.45

# %% [markdown]
# ### $k$NN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.15 0.25

# %%
err_test = 1 - knn.score(X_test, y_test) # Другой способ

# %%
err_test
# Out:
# 0.25

# %%
from sklearn.metrics import confusion_matrix
conf_m_train = confusion_matrix(y_train, y_train_predict)
conf_m_test = confusion_matrix(y_test, y_test_predict)
print(conf_m_train, conf_m_test)
# Out:
# [[209  14]
#  [ 40  97]] [[61  5]
#  [25 29]]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
XPCAreducedTrain = pca.fit_transform(X_train)
XPCAreducedTest = pca.fit_transform(X_test)

print('Sklearn reduced X_train: \n', XPCAreducedTrain)
print('Sklearn reduced X_test: \n', XPCAreducedTest)
# Out:
# Sklearn reduced X_train:
#  [[ 7.30468428e-01 -2.99759251e-01]
#  [ 1.10699853e+00 -1.30764954e+00]
#  [-1.63323597e+00 -9.42368072e-01]
#  [ 1.63034961e+00  9.08514461e-01]
#  [ 3.12593061e-01 -6.45055906e-01]
#  [-2.77284812e+00  6.66596538e-01]
#  [ 2.07025096e+00 -7.70645531e-01]
#  [-8.16638659e-01 -2.86839912e-01]
#  [-2.05475524e+00  8.67766999e-01]
#  [-2.27526469e+00  2.45217056e-01]
#  [ 1.29335441e+00  1.06984973e+00]
#  [-2.48502383e+00  7.73761211e-01]
#  [ 2.33256581e+00 -3.70733549e-01]
#  [-4.99137733e-01  1.79400989e+00]
#  [ 1.52410132e+00  3.90955862e-01]
#  [ 2.30968904e+00 -8.45043367e-01]
#  [ 2.77909870e+00  2.61493582e-01]
#  [ 1.68901247e+00 -1.69559786e-01]
#  [ 2.25127124e+00  5.25604745e-01]
#  [-1.75529392e+00  7.50200961e-01]
#  [-9.27119001e-02 -1.13158031e+00]
#  [ 5.93116368e-01  2.21507189e+00]
#  [-6.33630946e-01 -1.68899974e+00]
#  [-1.46762564e+00 -1.47175510e+00]
#  [-8.23055349e-01 -1.13745968e+00]
#  [-5.10745125e-01  3.35607931e-01]
# ...

# %% [markdown]
# ### Подбор параметров

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=3) #or cv=3, which reduce  the error on the training set (best_cv_err) to 0.0
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.18333333333333335 10

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.15 0.25

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC
svc = SVC(gamma='auto') #or gamma='scale'
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# 0.15833333333333333 0.24166666666666667

# %% [markdown]
# ### Random Forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000, random_state=11)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.21666666666666667

# %%
trees_arr = np.arange(25, 100, 2)
test_err = []
train_err = []
oob_err = []
for trees in trees_arr:
    rf = ensemble.RandomForestClassifier(n_estimators = trees, oob_score=True)
    rf.fit(X_train, y_train)
    train_err.append(np.mean(y_train != rf.predict(X_train)))
    test_err.append(np.mean(y_test  != rf.predict(X_test)))
    oob_err.append(1 - rf.oob_score_)
    
plt.plot(trees_arr, train_err, 'c-o', label = 'train')
plt.plot(trees_arr, test_err, 'g-o', label = 'test')
plt.plot(trees_arr, oob_err, 'y-o', label = 'oob')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. trees Random forest')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Наблюдается переобучение
#
# Минимальное значение ошибки

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.18055555555555555

# %% [markdown]
# Оптимальное количество деревьев

# %%
trees_opt = trees_arr[test_err == np.min(test_err)]
print(trees_opt)
trees_opt = trees_opt[0]
# Out:
# [300 350 400 750]

# %% [markdown]
# ### Значимость признаков

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'VisITedResources' (0.171727)
#  2. feature 'Class_L' (0.148780)
#  3. feature 'AnnouncementsView' (0.134118)
#  4. feature 'Discussion' (0.129388)
#  5. feature 'Class_H' (0.091573)
#  6. feature 'Class_M' (0.055704)
#  7. feature 'ParentAnsweringSurvey' (0.032092)
#  8. feature 'ParentschoolSatisfaction' (0.028001)
#  9. feature 'gender' (0.023691)
# 10. feature 'Relation' (0.020169)
# 11. feature 'GradeID_G-02' (0.014217)
# 12. feature 'Semester' (0.014076)
# 13. feature 'Topic_IT' (0.011308)
# 14. feature 'GradeID_G-08' (0.011195)
# 15. feature 'GradeID_G-07' (0.011141)
# 16. feature 'GradeID_G-04' (0.010837)
# 17. feature 'Topic_French' (0.010744)
# 18. feature 'Topic_Arabic' (0.010171)
# 19. feature 'Topic_Science' (0.009217)
# 20. feature 'Topic_Math' (0.009161)
# 21. feature 'GradeID_G-06' (0.008104)
# 22. feature 'Topic_English' (0.006928)
# 23. feature 'Topic_Biology' (0.006470)
# 24. feature 'Topic_Spanish' (0.006327)
# ...

# %%
feature_names[[1, 0, 1]]
# Out:
# Index(['AnnouncementsView', 'VisITedResources', 'AnnouncementsView'], dtype='object')

# %%
d_first = 15
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'c')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 15)

# %%
d_first = 15
point=17
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[point:point+d_first]], align = 'center', color = 'c')
plt.xticks(range(d_first), feature_names[indices[point:point+d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 15)

# %% [markdown]
# ## Extremely Randomized Trees

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.14166666666666666

# %% [markdown]
# ## AdaBoost

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 100)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.10555555555555556 0.275

# %% [markdown]
# ## GBT
#
# Gradient Boosted Trees

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 150)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.005555555555555556 0.21666666666666667

# %%
trees_arr = np.arange(50, 1000, 50)
test_err = []
train_err = []
for trees in trees_arr:
    gbt = ensemble.GradientBoostingClassifier(n_estimators = trees)
    gbt.fit(X_train, y_train)
    train_err.append(np.mean(y_train != gbt.predict(X_train)))
    test_err.append(np.mean(y_test  != gbt.predict(X_test)))
    
plt.plot(trees_arr, train_err, 'c-o', label = 'train')
plt.plot(trees_arr, test_err, 'g-o', label = 'test')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. trees GBT')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.19166666666666668

# %% [markdown]
# Оптимальное количество деревьев

# %%
trees_opt = trees_arr[test_err == np.min(test_err)]
print(trees_opt)
trees_opt = trees_opt[0]
# Out:
# [200 400]

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 5)
XPCAreducedTrain = pca.fit_transform(X_train)
XPCAreducedTest = pca.fit_transform(X_test)

print('Sklearn reduced X_train: \n', XPCAreducedTrain)
print('Sklearn reduced X_test: \n', XPCAreducedTest)
# Out:
# Sklearn reduced X_train:
#  [[ 0.73046843 -0.29975925  0.98369832  0.64321781 -0.05440025]
#  [ 1.10699853 -1.30764954 -1.36050328  0.0862411  -0.57398686]
#  [-1.63323597 -0.94236807  0.52963835  0.085867    1.01139361]
#  ...
#  [ 0.18765456  1.13673925 -0.83879556  0.69260385 -0.45940224]
#  [ 2.13155875 -0.16536065 -0.70275852 -0.31914226 -0.38914305]
#  [-1.58446799 -0.80743715  0.72652668 -0.74973502  0.71382366]]
# Sklearn reduced X_test:
#  [[-2.83073884e-01 -5.82476143e-01 -8.85216921e-01 -1.38405952e-02
#   -1.02365642e-01]
#  [ 8.19556230e-01  9.18758235e-01 -8.69295849e-01  3.50972052e-01
#   -8.24013992e-01]
#  [-2.04557361e-01 -1.51361417e+00 -5.91333536e-01  3.83057065e-01
#   -5.25689445e-01]
#  [ 9.72123392e-01  2.35412500e+00  8.89480569e-01  1.04549547e-01
#   -4.55222335e-01]
#  [-1.68720490e+00  1.30600719e+00 -2.36654452e-01  7.02140176e-02
#    8.70707247e-01]
#  [-1.12301836e+00  4.41237056e-01  8.48553630e-01 -7.88813565e-01
#   -5.31087011e-01]
# ...

# %%
concatData = np.vstack((XPCAreducedTrain,XPCAreducedTest))
plt.figure(figsize = (12,5))
plt.scatter(concatData[:,0], concatData[:,1], alpha = 0.4 )
plt.show()

# %%
cmpnts=5
pca = PCA(n_components = cmpnts)
X_PCA = pca.fit_transform(X)
import math
from matplotlib import gridspec
N = cmpnts ** 2
cols = cmpnts
rows = int(math.ceil(N / cols))
gs = gridspec.GridSpec(rows, cols)
fig = plt.figure(figsize=(10,10))
count = 0
for i in range(cmpnts):
    for j in range(cmpnts):
        if i != j:
            ax = fig.add_subplot(gs[count])
            ax.title.set_text('C'+str(i)+' - C'+str(j))
            ax.scatter(X_PCA[:,i], X_PCA[:,j], alpha = .2)
            count = count + 1

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(XPCAreducedTrain, y_train)

err_train = np.mean(y_train != knn.predict(XPCAreducedTrain))
err_test  = np.mean(y_test  != knn.predict(XPCAreducedTest))

print(err_train, err_test)
# Out:
# 0.16111111111111112 0.325

# %%
from sklearn.decomposition import PCA
errors = []
for l in range(1,9):
    pca = PCA(n_components = l)
    XPCAreducedTrain = pca.fit_transform(X_train)
    XPCAreducedTest = pca.fit_transform(X_test)
    
    knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(XPCAreducedTrain, y_train)
    err_train = np.mean(y_train != knn.predict(XPCAreducedTrain))
    err_test  = np.mean(y_test  != knn.predict(XPCAreducedTest))
    
    errors.append([err_train, err_test])

print(errors)
# Out:
# [[0.23333333333333334, 0.325], [0.19722222222222222, 0.3], [0.18611111111111112, 0.31666666666666665], [0.1638888888888889, 0.31666666666666665], [0.16111111111111112, 0.325], [0.18055555555555555, 0.35], [0.15555555555555556, 0.3416666666666667], [0.1527777777777778, 0.3416666666666667]]

# %%
i_range = range(1,9)
arr_errors = np.array(errors)
y_train = arr_errors[:,0]
y_test = arr_errors[:,1]
plt.figure(figsize = (15,5))
line_train = plt.plot(i_range, y_train, 'c-o', label = 'train', lw=5)
line_test = plt.plot(i_range, y_test, 'g-o', label = 'test', lw = 5)
plt.title("График зависимости ошибки от количества используемых компонент")
plt.axis([0.0, 9.0, 0.0, 0.6])
plt.grid()
plt.show()

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)
#principal_components

# %%
pca_X = pd.DataFrame(data=principal_components,
                     columns = ['principal_component_1', 'principal_component_2'])
pca_X.head()
# Out:
#    principal_component_1  principal_component_2
# 0               1.826945              -0.000417
# 1               1.663882               0.099798
# 2               2.432753               0.725120
# 3               1.941726               0.645564
# 4               0.892928               0.640452

# %%
final_data = pd.concat([pca_X, y], axis=1)
final_data
# Out:
#      principal_component_1  principal_component_2  StudentAbsenceDays
# 0                 1.826945              -0.000417                   0
# 1                 1.663882               0.099798                   0
# 2                 2.432753               0.725120                   1
# 3                 1.941726               0.645564                   1
# 4                 0.892928               0.640452                   1
# 5                 0.687590               1.440810                   1
# 6                 2.460010               0.225204                   1
# 7                 1.533346               0.076041                   0
# 8                 0.854221               0.767393                   0
# 9                -0.561797               0.703070                   0
# 10               -1.091804               0.831091                   0
# 11                1.657184              -0.181501                   0
# ...

# %%
plt.figure(figsize = (5, 5))

plt.title('2 component PCA', fontsize = 20)
plt.scatter(final_data[final_data['StudentAbsenceDays'] == 1 ]['principal_component_1'],
            final_data[final_data['StudentAbsenceDays'] == 1 ]['principal_component_2'],
            alpha = 0.3,
            label = 'Above-7',
            color = 'g')

plt.scatter(final_data[final_data['StudentAbsenceDays'] == 0 ]['principal_component_1'],
            final_data[final_data['StudentAbsenceDays'] == 0 ]['principal_component_2'],
            alpha = 0.3,
            label = 'Under-7',
            color = 'r')

plt.xlabel('Principal component 1')
plt.ylabel('Principal component 2')
plt.legend()
plt.grid()

# %% [markdown]
# ## Нейронная сеть
#
# 1 скрытый слой на 100 нейронах

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 17)
from sklearn.neural_network import MLPClassifier
mlp_model = MLPClassifier(hidden_layer_sizes = (100, 1), solver = 'lbfgs', activation = 'logistic', random_state = 17)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100, 1), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=17, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.08928571428571429 0.2013888888888889

# %% [markdown]
# 2 скрытых слоя на 100 нейронах

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (100, 2), solver = 'lbfgs', activation = 'logistic', random_state = 17)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=17, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.12797619047619047 0.2152777777777778

# %% [markdown]
# На тестовой и тренировочной выборке ошибка уменьшилась

# %% [markdown]
# ## Подбор гиперпараметров
#
# Подбор оптимального значения параметра регуляризации alpha

# %%
alpha_arr = np.logspace(-4, 3, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (100, 2), solver = 'lbfgs', activation = 'logistic', random_state = 17)
    mlp_model.fit(X_train, y_train)
    
    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

plt.semilogx(alpha_arr, train_err, 'c-o', label = 'train')
plt.semilogx(alpha_arr, test_err, 'g-o', label = 'test')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.008928571428571428 0.16666666666666666

# %% [markdown]
# Оптимальное значение alpha

# %%
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt)
alpha_opt = alpha_opt[0]
# Out:
# [0.00562341]

# %% [markdown]
# Подбор оптимального количества нейронов

# %%
neurons = np.arange(10, 200, 10)
test_err = []
train_err = []
for neuron in neurons:
    mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (neuron,), solver = 'lbfgs', activation = 'logistic', random_state = 17)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))
    
plt.semilogx(neurons, train_err, 'c-o', label = 'train')
plt.semilogx(neurons, test_err, 'g-o', label = 'test')
plt.xlim([np.max(neurons), np.min(neurons)])
plt.title('Error vs. neurons')
plt.xlabel('neurons')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.18055555555555555

# %% [markdown]
# Оптимальное количество нейронов

# %%
neuron_opt = neurons[test_err == min_test_err]
print(neuron_opt)
neuron_opt = neuron_opt[0]
# Out:
# [ 60  70  80 150]

# %% [markdown]
# ### Классификатор с оптимальными значениями

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (neuron_opt, 2), solver = 'lbfgs', activation = 'logistic', random_state = 17)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.005623413251903491,
#               batch_size='auto', beta_1=0.9, beta_2=0.999, early_stopping=False,
#               epsilon=1e-08, hidden_layer_sizes=(60, 2),
#               learning_rate='constant', learning_rate_init=0.001, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=17, shuffle=True, solver='lbfgs',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.008928571428571428 0.16666666666666666

# %% [markdown]
# ## Результаты

# %% [markdown]
# Метод | err_train | err_test
# --- | --- | ---
# kNN | 0.15 | 0.25
# SVC | 0.15833333333333333 | 0.24166666666666667
# AdaBoost|0.10555555555555556 | 0.275
# neural network l1 | 0.08928571428571429 | 0.2013888888888889
# neural network l2 | 0.008928571428571428  | 0.16666666666666666
# RandomForest |0.0 | 0.18055555555555555
# GradientBoosting| 0.0 | 0.19166666666666668
# Extremely Randomized Trees| 0.0 | 0.14166666666666666

# %% [markdown]
#  Лучшие результаты показали метод  Extremely Randomized Trees (100) и метод neural network 2 слоя с оптимальным числом нейронов.
